# %%
# !pip install requests

# %%
import requests
import pandas as pd
from requests.exceptions import RequestException

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=a348f31c0a6d9d2364c5b4e073a2ec1c&language=en-US&page=1')

# %%
response.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg',
#   'genre_ids': [18, 80],
#   'id': 238,
#   'original_language': 'en',
#   'original_title': 'The Godfather',
#   'overview': 'Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.',
#   'popularity': 147.852,
#   'poster_path': '/3bhkrj58Vtu7enYsRolD1fZdja1.jpg',
#   'release_date': '1972-03-14',
#   'title': 'The Godfather',
#   'video': False,
#   'vote_average': 8.708,
#   'vote_count': 18973},
#  {'adult': False,
#   'backdrop_path': '/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'original_language': 'en',
#   'original_title': 'The Shawshank Redemption',
# ...

# %%
#Convert the json data to DataFrame
movie_data = pd.DataFrame(response.json()['results'])

# %%
movie_data.head(5)
# Out:
#    adult                     backdrop_path        genre_ids     id  \
# 0  False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg         [18, 80]    238
# 1  False  /kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg         [18, 80]    278
# 2  False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg         [18, 80]    240
# 3  False  /3f92DMBTFqr3wgXpfxzrb0qv8nG.jpg  [18, 36, 10752]    424
# 4  False  /90ez6ArvpO8bvpyIngBuwXOqJm5.jpg  [35, 18, 10749]  19404
#
#   original_language                original_title  \
# 0                en                 The Godfather
# 1                en      The Shawshank Redemption
# 2                en         The Godfather Part II
# 3                en              Schindler's List
# 4                hi  दिलवाले दुल्हनिया ले जायेंगे
#
#                                             overview  popularity  \
# 0  Spanning the years 1945 to 1955, a chronicle o...     147.852
# 1  Framed in the 1940s for the double murder of h...     107.671
# ...

# %%
#Retrieve only few features or columns (id , title, release_date, popularity, vote_average, vote_count)

# %% [markdown]
# Above , we retrieved only page1 data ,lets create a loop and load all the data

# %%
movie_data[['id','title','release_date','popularity','vote_average','vote_count']]
# Out:
#         id                                          title release_date  \
# 0      238                                  The Godfather   1972-03-14
# 1      278                       The Shawshank Redemption   1994-09-23
# 2      240                          The Godfather Part II   1974-12-20
# 3      424                               Schindler's List   1993-12-15
# 4    19404                    Dilwale Dulhania Le Jayenge   1995-10-20
# 5      389                                   12 Angry Men   1957-04-10
# 6      129                                  Spirited Away   2001-07-20
# 7   496243                                       Parasite   2019-05-30
# 8      155                                The Dark Knight   2008-07-16
# 9      497                                 The Green Mile   1999-12-10
# 10  372058                                     Your Name.   2016-08-26
# 11     680                                   Pulp Fiction   1994-09-10
# ...

# %%
movie_data.head(2)
# Out:
#    adult                     backdrop_path genre_ids   id original_language  \
# 0  False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg  [18, 80]  238                en
# 1  False  /kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg  [18, 80]  278                en
#
#              original_title  \
# 0             The Godfather
# 1  The Shawshank Redemption
#
#                                             overview  popularity  \
# 0  Spanning the years 1945 to 1955, a chronicle o...     147.852
# 1  Framed in the 1940s for the double murder of h...     107.671
#
#                         poster_path release_date                     title  \
# 0  /3bhkrj58Vtu7enYsRolD1fZdja1.jpg   1972-03-14             The Godfather
# 1  /q6y0Go1tsGEsmtFryDOJo3dEmqu.jpg   1994-09-23  The Shawshank Redemption
#
#    video  vote_average  vote_count
# 0  False         8.708       18973
# 1  False         8.705       24960

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1, 429):
    try:
        response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=a348f31c0a6d9d2364c5b4e073a2ec1c&language=en-US&page={}'.format(i))
        movie_data[['id','title','release_date','popularity','vote_average','vote_count']]
        df.append(movie_data, ignore_index=True)
    except RequestException as e:
        print(f"Request failed on page {i}: {e}")
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_18772\2145053991.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(movie_data, ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_18772\2145053991.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(movie_data, ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_18772\2145053991.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(movie_data, ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_18772\2145053991.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(movie_data, ignore_index=True)
# ...

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.to_csv('Movies.csv')
